# %%
#Install Dependencies
# !pip install ydata-profiling;

# %%
#Import Libs
from google.colab import files;
from ydata_profiling import ProfileReport;
from IPython.display import IFrame, display, HTML;
import pandas as pd;

# %%
#Import Database for Data Profiling (After Upload the Database for the Google Colab)
df = pd.read_csv('https://raw.githubusercontent.com/jrafa1607/DataScience-ML-AI/main/-%20Datasets/census.csv')

# %%
#Run the Data Profile
profile = ProfileReport(df)
profile.to_file(output_file='output.html')

# %%
#Download of Data Profile
files.download('/content/output.html')
